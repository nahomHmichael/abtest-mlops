# %%
# Load libraries
import sys, os, datetime
import matplotlib.pyplot as plt

import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# TODO: add your own path and change my_path variable before running your code 
# janerose ="D:\\10XAcademy\\Ad-campaign-performance" 
egide = "C:\\Users\Kamuzinzi N. Egide\\Documents\\Ten_academy\\week 2\\Ad-campaign-performance"
# my_path = janerose
my_path = egide
os.chdir(my_path)
path_to_module = os.path.abspath(os.getcwd()+"\\scripts")
if path_to_module not in sys.path:
    sys.path.append(path_to_module)

# %%
df = pd.read_csv("../data/clean_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                            auction_id experiment      date  \
# 0           2  0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  7/5/2020
# 1          16  008aafdf-deef-4482-8fec-d98e3da054da    exposed  7/4/2020
# 2          20  00a1384a-5118-4d1b-925b-6cdada50318d    exposed  7/6/2020
# 3          23  00b6fadb-10bd-49e3-a778-290da82f7a8d    control  7/8/2020
# 4          27  00ebf4a8-060f-4b99-93ac-c62724399483    control  7/3/2020
#
#    hour         device_make  platform_os                browser  aware
# 0     2               E5823            6  Chrome Mobile WebView      0
# 1    16  Generic Smartphone            6          Chrome Mobile      1
# 2     8  Generic Smartphone            6          Chrome Mobile      0
# 3     4    Samsung SM-A202F            6               Facebook      1
# 4    15  Generic Smartphone            6          Chrome Mobile      0

# %%
def encode_labels(df):
    date_encoder = preprocessing.LabelEncoder()
    device_encoder = preprocessing.LabelEncoder()
    browser_encoder = preprocessing.LabelEncoder()
    experiment_encoder = preprocessing.LabelEncoder()
    aware_encoder = preprocessing.LabelEncoder()
    
    df['date'] = date_encoder.fit_transform(df['date'])
    df['device_make'] = device_encoder.fit_transform(df['device_make'])
    df['browser'] = browser_encoder.fit_transform(df['browser'])
    df['experiment'] = experiment_encoder.fit_transform(df['experiment'])
    df['browser'] = aware_encoder.fit_transform(df['browser'])
    df['aware'] = aware_encoder.fit_transform(df['aware'])
    
    return df

# %%
def feature_data(df):
    
    browser_feature_df = df[["experiment", "hour", "date", 'device_make', 'browser', 'aware']] 
    platform_feature_df = df[["experiment", "hour", "date", 'device_make', 'platform_os', 'aware']] 

    return browser_feature_df, platform_feature_df

# %%
def save_encoded_df(df):
    
    broweser_df, platfrom_df = feature_data(df)
    broweser_df.save_csv("../Data/browser_featured_data.csv")
    platfrom_df.save_csv(platfrom_df, "../data/platform_featured_data.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'auction_id', 'experiment', 'date', 'hour', 'device_make',
#        'platform_os', 'browser', 'aware'],
#       dtype='object')

# %%
#split dataset in features and target variable
# feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = df.iloc[:,2:-1] # Features
y = df.aware # Target variable

# %%
cleaned_data = encode_labels(df)
cleaned_browser_df, cleaned_platform_df = feature_data(cleaned_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Kamuzinzi N. Egide\Documents\Ten_academy\week 2\abtest-mlops\notebooks\decision_tree.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kamuzinzi%20N.%20Egide/Documents/Ten_academy/week%202/abtest-mlops/notebooks/decision_tree.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> cleaned_data = encode_labels(df)
#       <a href='vscode-notebook-cell:/c%3A/Users/Kamuzinzi%20N.%20Egide/Documents/Ten_academy/week%202/abtest-mlops/notebooks/decision_tree.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> cleaned_browser_df, cleaned_platform_df = feature_data(cleaned_data)
#
# c:\Users\Kamuzinzi N. Egide\Documents\Ten_academy\week 2\abtest-mlops\notebooks\decision_tree.ipynb Cell 11 in encode_labels(df)
#       <a href='vscode-notebook-cell:/c%3A/Users/Kamuzinzi%20N.%20Egide/Documents/Ten_academy/week%202/abtest-mlops/notebooks/decision_tree.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> def encode_labels(df):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kamuzinzi%20N.%20Egide/Documents/Ten_academy/week%202/abtest-mlops/notebooks/decision_tree.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a>     date_encoder = preprocessing.LabelEncoder()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kamuzinzi%20N.%20Egide/Documents/Ten_academy/week%202/abtest-mlops/notebooks/decision_tree.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     device_encoder = preprocessing.LabelEncoder()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kamuzinzi%20N.%20Egide/Documents/Ten_academy/week%202/abtest-mlops/notebooks/decision_tree.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a>     browser_encoder = preprocessing.LabelEncoder()
#
# NameError: name 'preprocessing' is not defined

# %%
X
# Out:
#      experiment       date  hour         device_make  platform_os  \
# 0       exposed   7/5/2020     2               E5823            6
# 1       exposed   7/4/2020    16  Generic Smartphone            6
# 2       exposed   7/6/2020     8  Generic Smartphone            6
# 3       control   7/8/2020     4    Samsung SM-A202F            6
# 4       control   7/3/2020    15  Generic Smartphone            6
# ...         ...        ...   ...                 ...          ...
# 1238    exposed   7/5/2020    21  Generic Smartphone            6
# 1239    exposed   7/4/2020     1  Generic Smartphone            6
# 1240    control   7/9/2020     7  Generic Smartphone            6
# 1241    control  7/10/2020    16  Generic Smartphone            6
# 1242    exposed   7/3/2020     4  Generic Smartphone            6
#
#                     browser
# 0     Chrome Mobile WebView
# 1             Chrome Mobile
# 2             Chrome Mobile
# 3                  Facebook
# 4             Chrome Mobile
# ...                     ...
# 1238          Chrome Mobile
# 1239          Chrome Mobile
# 1240          Chrome Mobile
# 1241          Chrome Mobile
# 1242          Chrome Mobile
#
# [1243 rows x 6 columns]
